# %% [markdown]
# ## Intro

# %% [markdown]
# As I am sure it does for many, the word "abstract" makes me think of abstract art, such as that made by Picasso (the only abstract artist I know).
#
# I have downloaded (from https://www.kaggle.com/momanyc/museum-collection/version/1?select=artworks.csv) a dataset describing all artworks in the Museum of Modern Art (MoMA).
#
# According to https://artincontext.org/abstract-artists/, the top 10 most famous abstract artists are:
# * Wassily Kandinsky (1866 – 1944)
# * Piet Mondrian (1872 – 1944)
# * Kazimir Malevich (1878 – 1935)
# * Georgia O’Keeffe (1887 – 1986)
# * Mark Rothko (1903 – 1966)
# * Clyfford Still (1904 – 1980)
# * Willem de Kooning (1904 – 1997)
# * Franz Kline (1910 – 1962)
# * Jackson Pollock (1912 – 1956)
# * Helen Frankenthaler (1928 – 2011)
#
# __I would like to visualize how many paintings in the MoMA these artists have contributed.__

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data

# %%
# get the data
data = pd.read_csv("artworks.csv")
data
# Out:
#         Artwork ID                                              Title  \
# 0                2  Ferdinandsbrücke Project, Vienna, Austria, Ele...
# 1                3  City of Music, National Superior Conservatory ...
# 2                4  Villa near Vienna Project, Outside Vienna, Aus...
# 3                5  The Manhattan Transcripts Project, New York, N...
# 4                6  Villa, project, outside Vienna, Austria, Exter...
# ...            ...                                                ...
# 130257      217983                                        Seul/NY/MAX
# 130258      217984   Fluxus-Manifestatie in en Rond Kunsthandel Monet
# 130259      217985                             Fluxphone Compositions
# 130260      217986                                       Unidentified
# 130261      218011                           Portrait of Takako Saito
#
#        Artist ID                      Name  Date  \
# 0           6210               Otto Wagner  1896
# 1           7470  Christian de Portzamparc  1987
# 2           7605                Emil Hoppe  1903
# 3           7056           Bernard Tschumi  1980
# 4           7605                Emil Hoppe  1903
# ...          ...                       ...   ...
# 130257      4469             Nam June Paik   NaN
# 130258       NaN                       NaN  1962
# 130259     67695                 Ely Ramen  1969
# 130260       NaN                       NaN   NaN
# 130261     21398           George Maciunas   NaN
#
#                                                    Medium  \
# 0           Ink and cut-and-pasted painted pages on paper
# 1                       Paint and colored pencil on print
# 2       Graphite, pen, color pencil, ink, and gouache ...
# 3       Photographic reproduction with colored synthet...
# 4       Graphite, color pencil, ink, and gouache on tr...
# ...                                                   ...
# 130257                                                VHS
# 130258                                                VHS
# 130259                                           Cassette
# 130260                                           Cassette
# 130261                               Gelatin silver print
#
#                                                Dimensions Acquisition Date  \
# 0                      19 1/8 x 66 1/2" (48.6 x 168.9 cm)       1996-04-09
# 1                           16 x 11 3/4" (40.6 x 29.8 cm)       1995-01-17
# 2                       13 1/2 x 12 1/2" (34.3 x 31.8 cm)       1997-01-15
# 3                               20 x 20" (50.8 x 50.8 cm)       1995-01-17
# 4                        15 1/8 x 7 1/2" (38.4 x 19.1 cm)       1997-01-15
# ...                                                   ...              ...
# 130257                                                NaN       2008-10-08
# 130258                                                NaN       2008-10-08
# 130259                                                NaN       2008-10-08
# 130260                                                NaN       2008-10-08
# 130261  image: 7 1/2 × 7 1/2" (19.1 × 19.1 cm); sheet:...       2008-10-08
#
#                                                    Credit Catalogue  ...  \
# 0       Fractional and promised gift of Jo Carole and ...         Y  ...
# 1       Gift of the architect in honor of Lily Auchinc...         Y  ...
# 2                  Gift of Jo Carole and Ronald S. Lauder         Y  ...
# 3       Purchase and partial gift of the architect in ...         Y  ...
# 4                  Gift of Jo Carole and Ronald S. Lauder         Y  ...
# ...                                                   ...       ...  ...
# 130257  The Gilbert and Lila Silverman Fluxus Collecti...         N  ...
# 130258  The Gilbert and Lila Silverman Fluxus Collecti...         N  ...
# 130259  The Gilbert and Lila Silverman Fluxus Collecti...         N  ...
# 130260  The Gilbert and Lila Silverman Fluxus Collecti...         N  ...
# 130261  The Gilbert and Lila Silverman Fluxus Collecti...         N  ...
#
#        Classification Object Number Diameter (cm)  Circumference (cm)  \
# 0        Architecture      885.1996           NaN                 NaN
# 1        Architecture        1.1995           NaN                 NaN
# 2        Architecture        1.1997           NaN                 NaN
# 3        Architecture        2.1995           NaN                 NaN
# 4        Architecture        2.1997           NaN                 NaN
# ...               ...           ...           ...                 ...
# 130257          Media        FC5038           NaN                 NaN
# 130258          Media        FC5039           NaN                 NaN
# 130259          Media        FC5040           NaN                 NaN
# 130260          Media        FC5041           NaN                 NaN
# 130261     Photograph     3841.2008           NaN                 NaN
#
#         Height (cm)  Length (cm)  Width (cm)  Depth (cm)  Weight (kg)  \
# 0           48.6000          NaN    168.9000         NaN          NaN
# 1           40.6401          NaN     29.8451         NaN          NaN
# 2           34.3000          NaN     31.8000         NaN          NaN
# 3           50.8000          NaN     50.8000         NaN          NaN
# 4           38.4000          NaN     19.1000         NaN          NaN
# ...             ...          ...         ...         ...          ...
# 130257       0.0000          NaN      0.0000         0.0          NaN
# 130258       0.0000          NaN      0.0000         0.0          NaN
# 130259       0.0000          NaN      0.0000         0.0          NaN
# 130260       0.0000          NaN      0.0000         0.0          NaN
# 130261       0.0000          NaN      0.0000         0.0          NaN
#
#         Duration (s)
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 130257           NaN
# 130258           NaN
# 130259           NaN
# 130260           NaN
# 130261           NaN
#
# [130262 rows x 21 columns]

# %%
# modify the data: we only need the 10 abstract artists
artistlist = ["Wassily Kandinsky", "Piet Mondrian", "Kazimir Malevich", "Georgia O’Keeffe", "Mark Rothko", "Clyfford Still", "Willem de Kooning", "Franz Kline", "Jackson Pollock", "Helen Frankenthaler"]
absdata = data[data["Name"].isin(artistlist)]
absdata
# Out:
#         Artwork ID                                       Title Artist ID  \
# 7321          8398                                  de Kooning      3213
# 7911          8988                                Paris Review      1974
# 7990          9069                Untitled (Suprematist Cross)      3710
# 8082          9162  Vil'gel'mova Karusel' (Wilhelm's Carousel)      3710
# 8921         10001                Plate (folio 2) from (POEMS)      3213
# ...            ...                                         ...       ...
# 126134      198698      Postcard (Addressed to A.F. Del Marle)      4057
# 129271      207104      Postcard (Addressed to A.F. Del Marle)      4057
# 129272      207105      Postcard (Addressed to A.F. Del Marle)      4057
# 129273      207106      Postcard (Addressed to A.F. Del Marle)      4057
# 129274      207107      Postcard (Addressed to A.F. Del Marle)      4057
#
#                        Name                Date        Medium  \
# 7321      Willem de Kooning                1965    Lithograph
# 7911    Helen Frankenthaler                1967    Lithograph
# 7990       Kazimir Malevich  1920, printed 1973  Linoleum cut
# 8082       Kazimir Malevich                1914    Lithograph
# 8921      Willem de Kooning           1967-1988           NaN
# ...                     ...                 ...           ...
# 126134        Piet Mondrian           1926–1927  Ink on paper
# 129271        Piet Mondrian                1926  Ink on paper
# 129272        Piet Mondrian                1926  Ink on paper
# 129273        Piet Mondrian                1927  Ink on paper
# 129274        Piet Mondrian                1927  Ink on paper
#
#                                                Dimensions Acquisition Date  \
# 7321                            29 x 20" (73.6 x 50.8 cm)       1965-11-09
# 7911                            31 x 23" (78.7 x 58.4 cm)       1967-10-18
# 7990             sheet: 12 3/8 x 10 1/8" (31.4 x 25.7 cm)       2001-01-24
# 8082    composition: 14 1/4 × 20 15/16" (36.2 × 53.2 c...       2001-01-24
# 8921    irreg. composition  12 1/4 x 9 5/8" (31.2 x 24...       1990-01-16
# ...                                                   ...              ...
# 126134                     3 1/2 × 5 3/8" (8.9 × 13.7 cm)       2015-10-19
# 129271                     3 1/2 × 5 3/8" (8.9 × 13.7 cm)       2015-10-19
# 129272                     3 1/2 × 5 3/8" (8.9 × 13.7 cm)       2015-10-19
# 129273                     3 1/2 × 5 3/8" (8.9 × 13.7 cm)       2015-10-19
# 129274                     3 1/2 × 5 3/8" (8.9 × 13.7 cm)       2015-10-19
#
#                                                    Credit Catalogue  ...  \
# 7321    Gift of the Aspen Institute for Humanistic Stu...         Y  ...
# 7911                     Gift of Page, Arbitrio and Resen         Y  ...
# 7990             Gift of The Judith Rothschild Foundation         Y  ...
# 8082             Gift of The Judith Rothschild Foundation         Y  ...
# 8921                               Gift of Benjamin Shiff         N  ...
# ...                                                   ...       ...  ...
# 126134  Elaine Lustig Cohen Collection, Gift of Lawren...         N  ...
# 129271  Elaine Lustig Cohen Collection, gift of Lawren...         Y  ...
# 129272  Elaine Lustig Cohen Collection, gift of Lawren...         Y  ...
# 129273  Elaine Lustig Cohen Collection, gift of Lawren...         Y  ...
# 129274  Elaine Lustig Cohen Collection, gift of Lawren...         Y  ...
#
#           Classification  Object Number Diameter (cm)  Circumference (cm)  \
# 7321              Design       933.1965           NaN                 NaN
# 7911              Design      2285.1967           NaN                 NaN
# 7990               Print         3.2001           NaN                 NaN
# 8082               Print        14.2001           NaN                 NaN
# 8921    Illustrated Book      28.1990.1           NaN                 NaN
# ...                  ...            ...           ...                 ...
# 126134            Design  1297.2015.1-4           NaN                 NaN
# 129271            Design    1297.2015.1           NaN                 NaN
# 129272            Design    1297.2015.2           NaN                 NaN
# 129273            Design    1297.2015.3           NaN                 NaN
# 129274            Design    1297.2015.4           NaN                 NaN
#
#         Height (cm)  Length (cm)  Width (cm)  Depth (cm)  Weight (kg)  \
# 7321      73.600000          NaN   50.800000         NaN          NaN
# 7911      78.700000          NaN   58.400000         NaN          NaN
# 7990      31.400000          NaN   25.700000         NaN          NaN
# 8082      36.200000          NaN   53.200000         NaN          NaN
# 8921      31.200000          NaN   24.500000         NaN          NaN
# ...             ...          ...         ...         ...          ...
# 126134     8.890018          NaN   13.652527         NaN          NaN
# 129271     8.890018          NaN   13.652527         NaN          NaN
# 129272     8.890018          NaN   13.652527         NaN          NaN
# 129273     8.890018          NaN   13.652527         NaN          NaN
# 129274     8.890018          NaN   13.652527         NaN          NaN
#
#         Duration (s)
# 7321             NaN
# 7911             NaN
# 7990             NaN
# 8082             NaN
# 8921             NaN
# ...              ...
# 126134           NaN
# 129271           NaN
# 129272           NaN
# 129273           NaN
# 129274           NaN
#
# [409 rows x 21 columns]

# %%
absdata["Name"].value_counts().shape
# Out:
# (8,)

# %%
absdata["Name"].unique().shape
# Out:
# (8,)

# %% [markdown]
# ## Plot

# %%
# 1) Bar graph depicting num. works by artist
# plot
plt.figure(figsize = (20,10))

plt.xlabel(xlabel="Artist", fontsize=20)
plt.ylabel(ylabel="Number of Paintings", fontsize=20)
plt.title(label="Number of Paintings in MoMA by Top 10 Most Famous Abstract Artists", fontsize=28) # a mouthful

plt.bar(x = absdata["Name"].unique(), 
        height = absdata["Name"].value_counts(),
        color = "#FF5733")


plt.show()

# %%
# 2) Pie Chart Showing Percent of All MoMA Art Composed of Top 10 Abstract Artists' Paintings
plt.figure(figsize = (20,10))

plt.title(label="Percent of Paintings in MoMA by Top 10 Most Famous Abstract Artists vs Other Artists", fontsize=28) 

plt.pie(x=[len(data), len(absdata)], explode = [0.1, 0.1])
plt.legend(["All Artworks", "Artworks by Top 10 Most Famous Abstract Artists"])
plt.show()

# %%
print(len(absdata) / len(data))
# Out:
# 0.003139825889361441

# %% [markdown]
# As it turns out, these artists only contribute 0.3 % of all artwork in the MoMA. Still, the MoMA contains a gargantuan amount of art, so this is still an accomplishment for the artists.
